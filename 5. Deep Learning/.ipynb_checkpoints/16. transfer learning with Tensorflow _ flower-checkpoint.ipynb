# %% [markdown]
# (참고) : https://limjun92.github.io/assets/TensorFlow%202.0%ED%8A%9C%ED%86%A0%EB%A6%AC%EC%96%BC/6.%20%EC%9D%B4%EB%AF%B8%EC%A7%80/%5B%ED%8A%9C%ED%86%A0%EB%A6%AC%EC%96%BC4%5D%20%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C%EC%9A%B0%20%ED%97%88%EB%B8%8C%EB%A5%BC%20%EC%9D%B4%EC%9A%A9%ED%95%9C%20%EC%A0%84%EC%9D%B4%20%ED%95%99%EC%8A%B5/

# %%
#!pip install tensorflow-hub

# %%
import matplotlib.pylab as plt
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers

# %%
classifier_url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4"

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer(classifier_url, input_shape=IMAGE_SHAPE+(3,))
])

# %%
classifier.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_6 (KerasLayer)  (None, 1001)              3540265
#
# ...
# Total params: 3,540,265
# Trainable params: 0
# Non-trainable params: 3,540,265
# _________________________________________________________________

# %%
import numpy as np
import PIL.Image as Image

url = 'https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg'
grace_hopper = tf.keras.utils.get_file('image.jpg', url)
grace_hopper = Image.open(grace_hopper).resize(IMAGE_SHAPE)
grace_hopper
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
## 정규화
grace_hopper = np.array(grace_hopper)/255.0
grace_hopper.shape
# Out:
# (224, 224, 3)

# %%
## 예측
result = classifier.predict(grace_hopper[np.newaxis, ...])
result.shape
# Out:
# 1/1 [==============================] - 0s 460ms/step
# (1, 1001)

# %% [markdown]
# - 결과 값으로는 이미지에 대해 각 클래스의 확률을 계산한 1001개로 구성된 로짓(logit)의 요소 벡터(element vector)가 도출되고 이미지에 대한 각 클래스의 확률을 계산합니다.

# %%
# 최상위 클래스의 ID는 argmax로 확인할 수 있습니다

predicted_class = np.argmax(result[0], axis=-1)
predicted_class
# Out:
# 653

# %% [markdown]
# - movilenet에는 1000개의 클래스가 있는데 그중 653이라는 뜻

# %% [markdown]
# ##  라벨을 저장

# %%
lable_url = 'https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt'
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt', lable_url)
imagenet_labels = np.array(open(labels_path).read().splitlines())

# %%
plt.imshow(grace_hopper)
plt.axis('off')
predicted_class_name = imagenet_labels[predicted_class]
_ = plt.title("Prediction: " + predicted_class_name.title())

# %% [markdown]
# - 지금 뭐한 거야??
#
#     - mobilenetv2를 다운 받아서 어떤 사진을 넣고 결과를 물어 본 것

# %% [markdown]
# ## 꽃 데이터 예측해보자

# %%
data_root = tf.keras.utils.get_file(
  'flower_photos','https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
   untar=True)

# %% [markdown]
# ## rescale 및 라벨 인식

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
image_data = image_generator.flow_from_directory(str(data_root), target_size=IMAGE_SHAPE)
# Out:
# Found 3670 images belonging to 5 classes.

# %% [markdown]
# ## image 배치 생성

# %%
for image_batch, label_batch in image_data:
    print("Image batch shape: ", image_batch.shape)
    print("Label batch shape: ", label_batch.shape)
    break
# Out:
# Image batch shape:  (32, 224, 224, 3)
# Label batch shape:  (32, 5)

# %% [markdown]
# ## 배치를 한 데이터셋의 예측 결과

# %%
result_batch = classifier.predict(image_batch)
result_batch.shape
# Out:
# 1/1 [==============================] - 0s 32ms/step
# (32, 1001)

# %%
predicted_class_names = imagenet_labels[np.argmax(result_batch, axis=-1)]
predicted_class_names
# Out:
# array(['daisy', 'hay', 'daisy', 'spider web', 'tray', 'shower cap',
#        'daisy', 'daisy', 'rapeseed', 'daisy', 'daisy', 'cardoon',
#        'honeycomb', 'street sign', 'daisy', 'feather boa', 'daisy', 'pot',
#        'balloon', 'feather boa', 'daisy', 'daisy', 'wool', 'mushroom',
#        'hummingbird', 'vase', 'birdhouse', 'hip', 'daisy', 'street sign',
#        'cup', 'harvester'], dtype='<U30')

# %% [markdown]
# ## 예측 결과 확인

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
    plt.subplot(6,5,n+1)
    plt.imshow(image_batch[n])
    plt.title(predicted_class_names[n])
    plt.axis('off')
_ = plt.suptitle("ImageNet predictions")

# %% [markdown]
# ## 피처 추출기를 생성

# %%
feature_extractor_url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4" #@param {type:"string"}

feature_extractor_layer = hub.KerasLayer(feature_extractor_url,
                                         input_shape=(224,224,3))

# %%
feature_batch = feature_extractor_layer(image_batch)
print(feature_batch.shape)
# Out:
# (32, 1280)

# %% [markdown]
#  - 각 이미지에 대해 길이가 1280인 벡터를 반환합니다:

# %% [markdown]
# ## Dense 레이어 추가
#
# - 피쳐 추출기 레이어의 변수를 프리즈(freeze)하여 새로운 분류기 레이어에 한정(modify)하여 학습하도록 합니다.

# %%
feature_extractor_layer.trainable = False

model = tf.keras.Sequential([
  feature_extractor_layer,
  layers.Dense(image_data.num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_7 (KerasLayer)  (None, 1280)              2257984
#
#  dense_1 (Dense)             (None, 5)                 6405
#
# ...
# Total params: 2,264,389
# Trainable params: 6,405
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# - tf.keras.Sequential에 허브 레이어를 감싸고 새로운 분류 레이어를 추가합니다.

# %% [markdown]
# ## 마지막 층 선언

# %%
predictions = model(image_batch)
predictions.shape
# Out:
# TensorShape([32, 5])

# %% [markdown]
# ## 모델 컴파일

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(),
  loss='categorical_crossentropy',
  metrics=['acc'])

# %% [markdown]
# ## callback 정의
# - 맞춤형 콜백(callback)을 사용하여 에포크별 평균 대신 각 배치의 손실과 정확도를 기록해서 학습 진행 상황을 시각화합니다.

# %%
class CollectBatchStats(tf.keras.callbacks.Callback):
    def __init__(self):
        self.batch_losses = []
        self.batch_acc = []

    def on_train_batch_end(self, batch, logs=None):
        self.batch_losses.append(logs['loss'])
        self.batch_acc.append(logs['acc'])
        self.model.reset_metrics()

# %% [markdown]
# ## 학습 진행
#
# - 간단하게 학습하기 위해 에포크(epoch)는 2로 설정합니다.

# %%
steps_per_epoch = np.ceil(image_data.samples/image_data.batch_size)

batch_stats_callback = CollectBatchStats()

history = model.fit(image_data, epochs=2,
                              steps_per_epoch=steps_per_epoch,
                              callbacks = [batch_stats_callback])
# Out:
# Epoch 1/2
# 115/115 [==============================] - 13s 87ms/step - loss: 0.7174 - acc: 0.7812
# Epoch 2/2
# 115/115 [==============================] - 10s 88ms/step - loss: 0.4694 - acc: 0.8438

# %% [markdown]
# ## 결과 plot

# %%
plt.figure()
plt.ylabel("Loss")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(batch_stats_callback.batch_losses);

# %%
plt.figure()
plt.ylabel("Accuracy")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(batch_stats_callback.batch_acc);

# %% [markdown]
# ## 예측 결과 확인

# %%
class_names = sorted(image_data.class_indices.items(), key=lambda pair:pair[1])
class_names = np.array([key.title() for key, value in class_names])
class_names
# Out:
# array(['Daisy', 'Dandelion', 'Roses', 'Sunflowers', 'Tulips'],
#       dtype='<U10')

# %% [markdown]
# - 이전의 그림을 다시 보려면 먼저 정리된 클래스 이름의 리스트를 가져옵니다:

# %%
predicted_batch = model.predict(image_batch)
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]
# Out:
# 1/1 [==============================] - 0s 490ms/step

# %% [markdown]
# - 모델을 통해 이미지 배치를 실행하고 인덱스를 클래스 이름으로 변환합니다.

# %%
## 결과 출력

label_id = np.argmax(label_batch, axis=-1)

plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
    plt.subplot(6,5,n+1)
    plt.imshow(image_batch[n])
    color = "green" if predicted_id[n] == label_id[n] else "red"
    plt.title(predicted_label_batch[n].title(), color=color)
    plt.axis('off')
_ = plt.suptitle("Model predictions (green: correct, red: incorrect)")

# %% [markdown]
# ## 모델 내보내기

# %%
import time
t = time.time()

export_path = "./{}".format(int(t))
model.save(export_path, save_format='tf')

export_path
# Out:
# INFO:tensorflow:Assets written to: ./1696675603\assets
# INFO:tensorflow:Assets written to: ./1696675603\assets
# './1696675603'

# %% [markdown]
# ## 동일한 결과를 내는지 확인

# %%
reloaded = tf.keras.models.load_model(export_path)

# %%
result_batch = model.predict(image_batch)
reloaded_result_batch = reloaded.predict(image_batch)
# Out:
# ...
# 1/1 [==============================] - 1s 520ms/step

# %%
abs(reloaded_result_batch - result_batch).max()
# Out:
# 0.0
