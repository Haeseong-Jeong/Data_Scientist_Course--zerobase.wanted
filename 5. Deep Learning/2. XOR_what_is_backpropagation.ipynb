# %%
import numpy as np

x = np.array([
    [0,0],
    [1,0],
    [0,1],
    [1,1]    
])

y = np.array([[0], [1], [1], [0]])

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(2, activation='sigmoid', input_shape=(2,)), # 두개 입력 -> 두 개출력
    tf.keras.layers.Dense(1, activation='sigmoid') # 위에서 나온 두개 받고 1개 출력
])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1), loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x,y, epochs=1000, batch_size=1) # 한번에 몇개 데이터를 사용할까
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 3ms/step - loss: 0.3003
# Epoch 2/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2960
# Epoch 3/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2920
# Epoch 4/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2882
# Epoch 5/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2846
# Epoch 6/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2814
# Epoch 7/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2786
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2758
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2735
# Epoch 10/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2714
# Epoch 11/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2695
# Epoch 12/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2678
# ...

# %%
model.predict(x)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[0.44426873],
#        [0.42472515],
#        [0.7322931 ],
#        [0.38189644]], dtype=float32)

# %%
hist.history['loss']
# Out:
# [0.30029743909835815,
#  0.29600241780281067,
#  0.2920088469982147,
#  0.2882087528705597,
#  0.28464171290397644,
#  0.28142523765563965,
#  0.278584748506546,
#  0.2758047580718994,
#  0.27348533272743225,
#  0.27140387892723083,
#  0.26952069997787476,
#  0.2678457498550415,
#  0.2663984000682831,
#  0.2651045322418213,
#  0.26391661167144775,
#  0.2628658413887024,
#  0.2621006965637207,
#  0.2612890899181366,
#  0.26067280769348145,
#  0.26005688309669495,
#  0.2594555616378784,
#  0.2589643895626068,
#  0.25851303339004517,
#  0.25811681151390076,
#  0.2578010559082031,
#  0.2575092613697052,
#  0.25713956356048584,
#  0.2569827735424042,
#  0.2567845284938812,
#  0.2564985752105713,
#  0.2564065158367157,
#  0.2562794089317322,
#  0.2561579942703247,
#  0.25599876046180725,
#  0.2559957802295685,
#  0.25591564178466797,
#  0.2558259963989258,
#  0.2557520270347595,
#  0.2556900978088379,
#  0.25562432408332825,
#  0.2555822730064392,
#  0.2555408179759979,
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(hist.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.show()

# %% [markdown]
# ## 레이어가 2개 이상일때 ...
#
# 우리는 레이어가 한개면 예측값  yhat - 실제값 y 를 에러로 계산해서 에러를 줄여나가는 방식을 사용했다.
#
# 근데 레이어가 여러개라 생각해보자....
# 중간에서 n-1에서 n층으로 넘어갈 때의 에러는 어떻게 구할 것인가??...
# 여기서는 알려줄 답도 없는 상황인데 어찌할까... 하면서 딥러닝의 빙하기가 시작됬다?
#
# 그러다 맨 끝 에러를 역으로 전파하자는 역전파의 개념이 등장했다.
# (여기서 에러는 미분(기울기)를 전달하는것)
#
# 근데... sigmoid는 0 or 1 값을 가지며... 그때 기울기는 0이다.. 그렇다면?
#
# 뒤로 전달하면 0으로 언젠가 전달값이 사라져 버리는 베니싱 현상이 발생한다....
#
# 이럴때 사용하는 것이 relu다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
