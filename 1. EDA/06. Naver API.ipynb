# %% [markdown]
# # 06. Naver API

# %% [markdown]
# ## 1. 네이버 API 등록
#
# - 네이버 개발자 센터 : https://developers.naver.com/main/
# - 서비스 API
#     - 오픈 AIP이용 신청
#     - Application  등록
#     - Application  이름 ds_study
#     - 사용 API
#         - 검색
#         - 데이터랩(검색어트렌드)
#         - 데이터랩(쇼핑인사이트)
#
#     - 환경추가
#         - WEB 설정 : http://localhost
#
#     - 사용자 정보
#         - Client ID: scZvFl_8tCWEcdiQ3KzB
#         - Client PW: cDgipvIoPe
#         - https://developers.naver.com/apps/#/myapps/scZvFl_8tCWEcdiQ3KzB/overview

# %% [markdown]
# - 개발가이드 : https://developers.naver.com/docs/serviceapi/search/blog/blog.md#python

# %% [markdown]
# - urllib : http 프로토콜에 따라서 서버의 요청/응답을 처리하기 위한 모듈
# - urllib.request : 클라이언트의 요청을 처리하는 모듈
# - urllib.parse : url 주소에 대한 분석

# %% [markdown]
# # 블로그 검색 : blog

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "scZvFl_8tCWEcdiQ3KzB"
client_secret = "cDgipvIoPe"

encText = urllib.parse.quote("파이썬") # 검색할 단어
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 11 Jul 2023 14:26:34 +0900",
# 	"total":398281,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b> 학원 다녀본 후기",
# 			"link":"https:\/\/blog.naver.com\/wkddpfka1\/223123747880",
# 			"description":"취업을 위해서 <b>파이썬<\/b> 독학을 했는데요. 전공자가 아니라 기본기부터 헷갈린다는 문제가 있었어요. 하지만 <b>파이썬<\/b> 학원을 다니며 해결되었어요. 제가 다니고 있는 KIC 캠퍼스에요. 교재 하나 들고 유튜브... ",
# 			"bloggername":"우당탕탕 자취생 블로그",
# 			"bloggerlink":"blog.naver.com\/wkddpfka1",
# 			"postdate":"20230608"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>학원을 다니면서 공부해야하는 이유",
# 			"link":"https:\/\/blog.naver.com\/sow723\/223024072662",
# 			"description":"개발자와는 전혀 관계 없던 제가 <b>파이썬<\/b>학원을 다니면서 이 쪽으로 취업에 성공할 줄이야 아무도... 그래서 일단 비전공자도 쉽게 배울 수 있다는 언어를 배우기 위해서 #<b>파이썬<\/b>학원 을 다녀보게 되었습니다.... ",
# 			"bloggername":"Onelog",
# 			"bloggerlink":"blog.naver.com\/sow723",
# 			"postdate":"20230222"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 자격증 취득 수업 내용 정리!",
# 			"link":"https:\/\/blog.naver.com\/eunoia1017\/222968873209",
# ...

# %%
response, response.getcode(), response.code, response.status
# Out:
# (<http.client.HTTPResponse at 0x23838b47be0>, 200, 200, 200)

# %%
# print(response) 그냥 출력하면 볼수없음.
# 글자로 읽을 경우 decode utf-8 설정 해야함.
# 위에서  response_body = response.read()


print(response_body.decode("utf-8"))
# Out:
# {
# 	"lastBuildDate":"Tue, 11 Jul 2023 14:23:46 +0900",
# 	"total":398303,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b> 학원 다녀본 후기",
# 			"link":"https:\/\/blog.naver.com\/wkddpfka1\/223123747880",
# 			"description":"취업을 위해서 <b>파이썬<\/b> 독학을 했는데요. 전공자가 아니라 기본기부터 헷갈린다는 문제가 있었어요. 하지만 <b>파이썬<\/b> 학원을 다니며 해결되었어요. 제가 다니고 있는 KIC 캠퍼스에요. 교재 하나 들고 유튜브... ",
# 			"bloggername":"우당탕탕 자취생 블로그",
# 			"bloggerlink":"blog.naver.com\/wkddpfka1",
# 			"postdate":"20230608"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>학원을 다니면서 공부해야하는 이유",
# 			"link":"https:\/\/blog.naver.com\/sow723\/223024072662",
# 			"description":"개발자와는 전혀 관계 없던 제가 <b>파이썬<\/b>학원을 다니면서 이 쪽으로 취업에 성공할 줄이야 아무도... 그래서 일단 비전공자도 쉽게 배울 수 있다는 언어를 배우기 위해서 #<b>파이썬<\/b>학원 을 다녀보게 되었습니다.... ",
# 			"bloggername":"Onelog",
# 			"bloggerlink":"blog.naver.com\/sow723",
# 			"postdate":"20230222"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 자격증 취득 수업 내용 정리!",
# 			"link":"https:\/\/blog.naver.com\/eunoia1017\/222968873209",
# ...

# %% [markdown]
# ## 책 검색 : book

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "scZvFl_8tCWEcdiQ3KzB"
client_secret = "cDgipvIoPe"

encText = urllib.parse.quote("파이썬") # 검색할 단어
url = "https://openapi.naver.com/v1/search/book?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 11 Jul 2023 14:26:38 +0900",
# 	"total":895,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"모두의 파이썬 (20일 만에 배우는 프로그래밍 기초)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32463987904",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3246398\/32463987904.20230711120131.jpg",
# 			"author":"이승찬",
# 			"discount":"4000",
# 			"publisher":"길벗",
# 			"pubdate":"20181009",
# 			"isbn":"9791160505856",
# 			"description":"파이썬 분야 & 어린이 코딩 교육 분야\n2년 연속 베스트셀러! 개정판 출간!\n\n즐겁게 시작하는 나의 첫 프로그래밍!\n프로그래밍을 한 번도 해본 적이 없어도 괜찮다. 파이썬이 무엇인지 몰라도 상관 없다. 어려운 개념과 복잡한 이론 설명은 최대한 줄이고, 초보자가 프로그래밍을 쉽게 배울 수 있도록 짧고 간단한 예제로 내용을 구성했다. 처음부터 모든 것을 다 이해하지 못해도 괜찮다. 프로그램을 따라서 입력하고, 실행 결과를 확인하며, 책에서 알려주는 대로 에러를 수정해 보자. 어느새 파이썬 프로그램으로 멋진 그림을 그리고, 계산을 하고, 간단한 게임을 만들고, 수학 문제를 푸는 자신을 발견하게 될 것이다. \n\n* 《모두의 파이썬, 개정 2판》에서는 파이썬 최신 버전을 반영하였으며, Day 19 ‘파이썬으로 수학 문제 풀기 1’의 내용을 중학 수학 2015 개정교육과정에 맞춰 수정 및 보완하였습니다. 나머지 내용은 초판과 동일합니다."
# 		},
# 		{
# ...

# %% [markdown]
# ## 영화 검색 : movie(영화 API 지원 종료되었다고 하네요. ㅠㅠ)

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "scZvFl_8tCWEcdiQ3KzB"
client_secret = "cDgipvIoPe"

encText = urllib.parse.quote("파이썬") # 검색할 단어
url = "https://openapi.naver.com/v1/search/movie?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[18], line 15
#      13 request.add_header("X-Naver-Client-Id",client_id)
#      14 request.add_header("X-Naver-Client-Secret",client_secret)
# ---> 15 response = urllib.request.urlopen(request)
#      16 rescode = response.getcode()
#      17 if(rescode==200):
#
# File ~\miniconda3\envs\ds_study\lib\urllib\request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File ~\miniconda3\envs\ds_study\lib\urllib\request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# ...

# %%
## 카페 검색 : cafearticle

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "scZvFl_8tCWEcdiQ3KzB"
client_secret = "cDgipvIoPe"

encText = urllib.parse.quote("파이썬") # 검색할 단어
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 11 Jul 2023 14:32:00 +0900",
# 	"total":168303,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b> 하실 분 계실까요?",
# 			"link":"http:\/\/cafe.naver.com\/isajime\/5573710",
# 			"description":"혼자 <b>파이썬<\/b> 공부하려니 심심하고 진도가 잘 안나가네요. ㅎㅎ 프로그래밍 언어라 많이 어려워서... 왜 <b>파이썬<\/b>을 하고 싶은지 댓글로 남겨주시면 오래 같이 하실분을 컨텍할까 하는데요( 좀 그런가요? ㅎㅎ) 아무도 지원... ",
# 			"cafename":"고.우.리 일산아지매",
# 			"cafeurl":"https:\/\/cafe.naver.com\/isajime"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 프로그래밍 초보자도 가능한 이유!",
# 			"link":"http:\/\/cafe.naver.com\/winspec\/556447",
# 			"description":"<b>파이썬<\/b> 프로그래밍 초보자 안녕하세요! 오늘은 <b>파이썬<\/b> 프로그래밍 초보자도 가능한 방법 알려드리겠습니다! <b>파이썬<\/b> 프로그래밍 언어는 개발에서 대표적으로 쓰이는 언어인데요! 진입장벽이 낮아 비전공자 분들도... ",
# 			"cafename":"윈스펙｜부트캠프, 강연, 내일배움카드...",
# 			"cafeurl":"https:\/\/cafe.naver.com\/winspec"
# 		},
# 		{
# 			"title":"백엔드로 <b>파이썬<\/b> 장고는 잘 사용하지 않나요?",
# 			"link":"http:\/\/cafe.naver.com\/hacosa\/320174",
# ...

# %% [markdown]
# ## 쇼핑 검색 : shop

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "scZvFl_8tCWEcdiQ3KzB"
client_secret = "cDgipvIoPe"

encText = urllib.parse.quote("파이썬") # 검색할 단어
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 11 Jul 2023 14:32:35 +0900",
# 	"total":141128,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[길벗]<b>파이썬<\/b> 무작정 따라하기[1017218036]",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=34118710994",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3411871\/34118710994.jpg",
# 			"lprice":"13830",
# 			"hprice":"",
# 			"mallName":"위메프",
# 			"productId":"34118710994",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"출산\/육아",
# 			"category2":"교구",
# 			"category3":"학습교구",
# 			"category4":"기타교구"
# 		},
# 		{
# 			"title":"Do it 점프 투 <b>파이썬<\/b> 프로그래밍 언어 책 코딩",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40923069997",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4092306\/40923069997.jpg",
# 			"lprice":"19800",
# 			"hprice":"",
# 			"mallName":"인터파크쇼핑",
# 			"productId":"40923069997",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# ...

# %% [markdown]
# ## 백과사전 검색 : encyc

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "scZvFl_8tCWEcdiQ3KzB"
client_secret = "cDgipvIoPe"

encText = urllib.parse.quote("파이썬") # 검색할 단어
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 11 Jul 2023 14:33:07 +0900",
# 	"total":42,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3580815&cid=59088&categoryId=59096",
# 			"description":"‘<b>파이썬<\/b>’이다. 간결한 문법으로 입문자가 이해하기 쉽고, 다양한 분야에 활용할 수 있기 때문이다. 이 외에도 <b>파이썬<\/b>은 머신러닝, 그래픽, 웹 개발 등 여러 업계에서 선호하는 언어로 꾸준히... ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4749_000_1\/20170118193349632_0CHSSS5Y6.png\/01_16.png?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/terms.naver.com\/entry.naver?docId=3607513&cid=58598&categoryId=59316",
# 			"description":" 컴퓨터 언어의 일종으로 간결하고 생산성 높은 프로그래밍 언어.  <b>파이썬<\/b>(python)은 프로그램을 설계하는 프로그래밍 언어 중 하나입니다. 컴퓨터는 0과 1을(이진수) 인식하여 작동하기 때문에 과거에는... ",
# 			"thumbnail":"http:\/\/openapi-dbscthumb.phinf.naver.net\/4751_000_3\/20170710213206672_OPHLG2VOW.jpg\/992_170575_10034.jpg?type=m160_160"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# ...

# %% [markdown]
# # 3. 상품 검색
# - "몰스킨"이라는 상품을 쇼핑에서 검색하기

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "scZvFl_8tCWEcdiQ3KzB"
client_secret = "cDgipvIoPe"

encText = urllib.parse.quote("몰스킨") # 검색할 단어
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 11 Jul 2023 14:46:14 +0900",
# 	"total":26969,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>몰스킨<\/b> 2024 위클리 18개월 다이어리 소프트커버 상품선택",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=39992373021",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3999237\/39992373021.20230513055543.jpg",
# 			"lprice":"32190",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"39992373021",
# 			"productType":"1",
# 			"brand":"몰스킨",
# 			"maker":"몰스킨",
# 			"category1":"생활\/건강",
# 			"category2":"문구\/사무용품",
# 			"category3":"다이어리\/플래너",
# 			"category4":"다이어리"
# 		},
# 		{
# 			"title":"<b>몰스킨<\/b> 클래식노트 플레인 소프트커버 포켓 Pocket",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=30656121375",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3065612\/30656121375.20220124025746.jpg",
# 			"lprice":"21840",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"30656121375",
# 			"productType":"1",
# ...

# %% [markdown]
# # 1. gen_search_url() 만들기
# - 위에서 본 형식을 우리가 직접 만드는 것이다.
# ```
# encText = urllib.parse.quote("몰스킨") # 검색할 단어
# url = "https://openapi.naver.com/v1/search/shop?query=" + encText # JSON 결과
# ```
# - 네이버 개발자센터(쇼핑) 참고: https://developers.naver.com/docs/serviceapi/search/shopping/shopping.md
#
# - 구조 설명
#     - base + API키워드.json + ?query검색어 + &검색시작위치 + &한 번에 표시할 검색 결과 개수
#     - 예시 : shop.json?query=%EC%A3%BC%EC%8B%9D&display=10&start=1

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_display = "&display=" + str(disp_num)
    
    return base + node + param_query + param_start + param_display

# %%
gen_search_url("shop", "pencle", 10, 3) # 10번째 페이지부터 3개씩 보여주세요
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=pencle&start=10&display=3'

# %%
# 2. gen_result_onepage() 만들기
import json
import datetime

def get_result_onepage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    print("[%s] URL Requests Success" % datetime.datetime.now())
    
    return json.loads(response.read().decode("utf-8"))

# %%
# 현재의 모든 날짜 데이터를 보여준다.
datetime.datetime.now()
# Out:
# datetime.datetime(2023, 7, 11, 15, 15, 54, 976989)

# %%
url = gen_search_url("shop","몰스킨", 1, 5) # 1번째 페이지부터 5개씩 보여주세요
one_result = get_result_onepage(url)
# Out:
# [2023-07-11 15:15:56.580501] URL Requests Success

# %%
# 1페이지에 5개 정보 => 딕셔너리 5개

one_result
# Out:
# {'lastBuildDate': 'Tue, 11 Jul 2023 15:15:56 +0900',
#  'total': 26972,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '<b>몰스킨</b> 2024 위클리 18개월 다이어리 소프트커버 상품선택',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=39992373021',
#    'image': 'https://shopping-phinf.pstatic.net/main_3999237/39992373021.20230513055543.jpg',
#    'lprice': '32190',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '39992373021',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 클래식노트 플레인 소프트커버 포켓 Pocket',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=30656121375',
#    'image': 'https://shopping-phinf.pstatic.net/main_3065612/30656121375.20220124025746.jpg',
#    'lprice': '21840',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '30656121375',
#    'productType': '1',
#    'brand': '몰스킨',
# ...

# %%
# 5개 보여달라했으니까 5개가 있을 것이다. value값은 리스트
    
one_result["items"][0]["title"]
# Out:
# '<b>몰스킨</b> 2024 위클리 18개월 다이어리 소프트커버 상품선택'

# %%
one_result["items"][0]["link"]
# Out:
# 'https://search.shopping.naver.com/gate.nhn?id=39992373021'

# %%
one_result["items"][0]["mallName"]
# Out:
# '네이버'

# %% [markdown]
# # 3. get_fields() 만들기

# %%
import pandas as pd

def get_fields(json_data):
    title = [each["title"] for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mall_name = [each["mallName"] for each in json_data["items"]]
    
    result_pd = pd.DataFrame(
        {
            "title" : title,
            "link" : link,
            "lprice" : lprice,
            "mall" : mall_name
        },
        columns=["title", "lprice", "link", "mall"]
    )
    
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                                title  lprice  \
# 0           <b>몰스킨</b> 2024 위클리 18개월 다이어리 소프트커버 상품선택   32190
# 1               <b>몰스킨</b> 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2          [<b>몰스킨</b>] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 3  시리즈 역시즌 50 series <b>몰스킨</b> 집업 아우터 셔츠 SASFW22...  110270
# 4             <b>몰스킨</b> 2024 위클리 가로형 18개월 다이어리 하드커버   32190
#
#                                                 link         mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %% [markdown]
# ## 4. delete_tag 만들기

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>","")
    input_str = input_str.replace("</b>","")
    
    return input_str

# %% [markdown]
# ## get_fields 안에 delete_tag 함수 추가

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each["title"]) for each in json_data["items"]]
    link = [each["link"] for each in json_data["items"]]
    lprice = [each["lprice"] for each in json_data["items"]]
    mall_name = [each["mallName"] for each in json_data["items"]]
    
    result_pd = pd.DataFrame(
        {
            "title" : title,
            "link" : link,
            "lprice" : lprice,
            "mall" : mall_name
        },
        columns=["title", "lprice", "link", "mall"]
    )
    
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                            title  lprice  \
# 0              몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32190
# 1                  몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2             [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 3  시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270
# 4                몰스킨 2024 위클리 가로형 18개월 다이어리 하드커버   32190
#
#                                                 link         mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %% [markdown]
# # 지금까지 만든거 종합해서 한번에 실행해보자

# %%
url = gen_search_url("shop", "몰스킨", 1, 5)
json_result = get_result_onepage(url)
pd_result = get_fields(json_result)
# Out:
# [2023-07-11 15:26:01.143501] URL Requests Success

# %%
pd_result
# Out:
#                                            title  lprice  \
# 0              몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32190
# 1                  몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2             [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 3  시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270
# 4                몰스킨 2024 위클리 가로형 18개월 다이어리 하드커버   32190
#
#                                                 link         mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %% [markdown]
# # actMain() 만들기

# %%
for n in range(1, 1000, 100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_mol = []

for n in range(1, 1000, 100):
    url = gen_search_url("shop", "몰스킨", n, 100) # 1에서 100, 101에서 200 ...
    json_result = get_result_onepage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)
    
result_mol = pd.concat(result_mol)
# Out:
# [2023-07-11 15:32:09.388297] URL Requests Success
# [2023-07-11 15:32:09.670169] URL Requests Success
# [2023-07-11 15:32:09.938778] URL Requests Success
# [2023-07-11 15:32:10.195816] URL Requests Success
# [2023-07-11 15:32:10.479427] URL Requests Success
# [2023-07-11 15:32:10.774176] URL Requests Success
# [2023-07-11 15:32:11.229362] URL Requests Success
# [2023-07-11 15:32:11.515054] URL Requests Success
# [2023-07-11 15:32:11.899767] URL Requests Success
# [2023-07-11 15:32:12.179445] URL Requests Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
# drop=True : 기존에 있던 인덱스는 삭제
# inplace=True : 변경값 원본으로 유지

result_mol.reset_index(drop=True, inplace=True)
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result_mol.head()
# Out:
#                                            title  lprice  \
# 0              몰스킨 2024 위클리 18개월 다이어리 소프트커버 상품선택   32190
# 1                  몰스킨 클래식노트 플레인 소프트커버 포켓 Pocket   21840
# 2             [몰스킨] 2023-24년 18개월 다이어리(데일리, 위클리)   35000
# 3  시리즈 역시즌 50 series 몰스킨 집업 아우터 셔츠 SASFW22821KHL  110270
# 4                몰스킨 2024 위클리 가로형 18개월 다이어리 하드커버   32190
#
#                                                 link         mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  몰스킨공식온라인스토어
# 3  https://search.shopping.naver.com/gate.nhn?id=...          네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...          네이버

# %%
result_mol.tail()
# Out:
#                                 title  lprice  \
# 995                 몰스킨 21피노키오룰드 그린 L   43200
# 996  단톤 라이트 몰 스킨 반팔 커버 올 재킷 - 계열 4 88  277190
# 997      COS 코스 스트레이트 레그 코튼 몰스킨 팬츠 바지  139100
# 998      COS 코스 스트레이트 레그 코튼 몰스킨 팬츠 바지  139200
# 999      COS 코스 스트레이트 레그 코튼 몰스킨 팬츠 바지  139000
#
#                                                   link mall
# 995  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 996  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 997  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 998  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 999  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
result_mol["lprice"] = result_mol["lprice"].astype("float")
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ## to_excel() 만들기

# %%
#!pip install xlsxwriter
# Out:
# ...
#                                               0.0/153.0 kB ? eta -:--:--
#      -------------------------------------- 153.0/153.0 kB 9.5 MB/s eta 0:00:00
# ...

# %%
writer = pd.ExcelWriter("../data/06._molskin_diary_in_naver_shop.xlsx",engine="xlsxwriter")
result_mol.to_excel(writer, sheet_name="Sheet1")

workbook = writer.book
worksheet = writer.sheets["Sheet1"]
worksheet.set_column("A:A", 4) # 숫자의미는 셀 간격
worksheet.set_column("B:B", 60)
worksheet.set_column("C:C", 10)
worksheet.set_column("D:D", 10)
worksheet.set_column("E:E", 50)
worksheet.set_column("F:F", 10)

# C열은 가격컬럼으로 3가지색으로 나타내게 만듬
worksheet.conditional_format("C2:C1001", {"type": "3_color_scale"})
writer.save()
# Out:
# C:\Users\Sam\AppData\Local\Temp\ipykernel_13392\4137510491.py:14: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %% [markdown]
# # 6. 시각화

# %%
import set_matplotlib_hangul
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16,6))

sns.countplot(
    x = result_mol["mall"],
    data = result_mol,
    palette="RdYlGn",
    order=result_mol["mall"].value_counts().index   
)

plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(16,6))

sns.countplot(
    y = result_mol["mall"],
    data = result_mol,
    palette="RdYlGn",
    order=result_mol["mall"].value_counts().index   
)

#plt.xticks(rotation = 90)
plt.show()
